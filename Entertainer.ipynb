# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaDariniSivabalan/Unified-Mentor/blob/main/Entertainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from google.colab import files
u = files.upload()
# Out:
#      <input type="file" id="files-50109784-f94e-455c-a29a-c24f440daf89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50109784-f94e-455c-a29a-c24f440daf89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
v = files.upload()
# Out:
#      <input type="file" id="files-531f9ed1-fac7-4d63-8600-d56534b2e5c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-531f9ed1-fac7-4d63-8600-d56534b2e5c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
w = files.upload()
# Out:
#      <input type="file" id="files-81e8c2ba-7706-4440-b80e-df381e4022d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81e8c2ba-7706-4440-b80e-df381e4022d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_excel('Entertainer - Basic Info.xlsx')
df2 = pd.read_excel('Entertainer - Breakthrough Info.xlsx')
df3 = pd.read_excel('Entertainer - Last work Info.xlsx')

# %%
df1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
df2.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
df3.head()
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entertainer           70 non-null     object
#  1   Gender (traditional)  70 non-null     object
#  2   Birth Year            70 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Year of Breakthrough/#1 Hit/Award Nomination  70 non-null     int64
#  2   Breakthrough Name                             70 non-null     object
#  3   Year of First Oscar/Grammy/Emmy               64 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.3+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Entertainer                         70 non-null     object
#  1   Year of Last Major Work (arguable)  70 non-null     int64
#  2   Year of Death                       30 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df1.equals(df2)
# Out:
# False

# %%
df2.equals(df3)
# Out:
# False

# %%
df3.equals(df1)
# Out:
# False

# %%
df1.isnull().sum()
# Out:
# Entertainer             0
# Gender (traditional)    0
# Birth Year              0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# Entertainer                                     0
# Year of Breakthrough/#1 Hit/Award Nomination    0
# Breakthrough Name                               0
# Year of First Oscar/Grammy/Emmy                 6
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# Entertainer                            0
# Year of Last Major Work (arguable)     0
# Year of Death                         40
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df2_clean = df2.dropna()

# %%
df2_clean.isnull().sum()
# Out:
# Entertainer                                     0
# Year of Breakthrough/#1 Hit/Award Nomination    0
# Breakthrough Name                               0
# Year of First Oscar/Grammy/Emmy                 0
# dtype: int64

# %%
df2_clean
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 64    Stevie Wonder                                          1963
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                         19                           2009.0
# ...

# %%
df3_clean = df3.dropna()

# %%
df3_clean
# Out:
#           Entertainer  Year of Last Major Work (arguable)  Year of Death
# 3         Bette Davis                                1989         1989.0
# 5         Bing Crosby                                1974         1977.0
# 6            Bob Hope                                1972         2003.0
# 8      Carole Lombard                                1942         1942.0
# 9       Carrie Fisher                                2016         2016.0
# 10         Cary Grant                                1966         1986.0
# 11    Charlie Chaplin                                1967         1977.0
# 12          Clara Bow                                1933         1965.0
# 13        Clark Gable                                1960         1960.0
# 15    Debbie Reynolds                                2006         2016.0
# 20        Ed Sullivan                                1973         1974.0
# 23      Elvis Presley                                1977         1977.0
# ...

# %%
m_df = pd.merge(df1, df2_clean, on='Entertainer', how ='left')

# %%
m_df
# Out:
#         Entertainer Gender (traditional)  Birth Year  \
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
#     Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                         2008.0
# 1                                         1999.0
# 2                                         1967.0
# 3                                         1934.0
# 4                                         1952.0
# ...

# %%
m_df['Age'] = 2024 - m_df['Birth Year']
m_df['Decade of Breakthout'] = m_df['Year of Breakthrough/#1 Hit/Award Nomination'] // 10 * 10

# %%
m_df.to_csv('cleaned_df12.csv',index =False )
